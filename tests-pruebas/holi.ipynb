# %% [markdown]
# # Lenguajes de Programación
#
# ## Primera prueba en Jupyter
#
# Este notebook es una prueba inicial para verificar que el entorno funciona correctamente.

# %%
mensaje = "Esto es una prueba"
print(mensaje)
print(type(mensaje))
